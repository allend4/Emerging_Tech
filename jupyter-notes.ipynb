# %% [markdown]
# # Jupyter tutorial and notes
# #### cheatsheet
# ***

# %% [markdown]
# # Lists

# %%
# lists - markdown

# to create a list:
# 1. it should be written in markdown.
# 2. numbered list.

# %% [markdown]
# to create a list:
# 1. it should be written in markdown.
# 2. numbered list.
#
# ***

# %% [markdown]
# # Headings

# %%
#  Use #s followed by a blank space for notebook titles and section headings

# title
## major headings
### subheadings
#### 4th level subheadings

# %% [markdown]
# # title
# ## major headings
# ### subheadings
# #### 4th level subheadings
#
# ***

# %% [markdown]
# # Links

# %%
# [link text](http://url)

# %% [markdown]
# [Central Limit Theorem](https://en.wikipedia.org/wiki/Central_limit_theorem)

# %% [markdown]
# ***

# %% [markdown]
# # Adding images
# 3 Ways to Add Images to Your Jupyter Notebook

# %% [markdown]
# ***1*** We can add images from your local drive by providing the path to the file.

# %%
# from IPython import display
# display.Image("./image.png")

# %% [markdown]
# ***2*** Add an image from a URL

# %%
# from IPython import display
# display.Image("URL of the image")

# %% [markdown]
# ***3*** Embed an image by Base64 Encode-Decode

# %% [markdown]
# [BASE64 Image](https://www.base64-image.de/) can be used to convert images to base64

# %%
from IPython import display
from base64 import b64decode
base64_data = "..."
display.Image(b64decode(base64_data))

# %%
base64_image = "..."
display.Image(b64decode(base64_image))

# %% [markdown]
# ***

# %% [markdown]
# # Horizontal lines
# three asterisks

# %%
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Math

# %%
# \sum_i
# $ mathematical symbols $ - math needs to be surrounded by dollar symbol

# %% [markdown]
# $ \sum_i $

# %%
# equation example with and without $

# %% [markdown]
# \sum_i (y_i - mx_i - c)^2

# %% [markdown]
# $ \sum_i (y_i - mx_i - c)^2 $

# %% [markdown]
# equations can be highlighted and broken down into tex command. <br>
# [TeX](https://en.wikipedia.org/wiki/TeX) is a popular means of typesetting complex mathematical formulae.

# %%
# $ alignso the left, while $$ aligns to the centre

# %% [markdown]
# $ \sum_i (y_i - mx_i - c)^2 $
# $$ \sum_i (y_i - mx_i - c)^2 $$

# %% [markdown]
# ***
